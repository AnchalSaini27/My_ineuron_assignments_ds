# %% [markdown]
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
# *
# 'hello'
# -87.8
# - -
# /
# +
# 6
#
# Ans:-
#
#
#      *       expression
#     'hello'  value
#     -87.8    value
#     -        expression
#     /        expression
#     +        expression
#     6        value
#
#
#
#
#
#
#
# 2.What is the difference between string and variable?
#
#
# Ans:-
# String - A string is the values inside the quotes assigned to a string.
# Variable - A variable is the name of the location in the primary memory of our computer. This can be chosen by us.
# A variable can hold a string, but a string can't hold a variable
#
#
#
#
# 3. Describe three different data types.
#
#
# Ans:-
# 1. string data type - str
#    In python string is a sequence of characters represented by either single or double quotes.
# 2. numeric data type - int, float, complex
#    In Python numeric data type is used to hold numeric values.
# 3. boolean data type - bool
#   Python boolean data type holds either True or False
#
#
#
#
#
# 4. What is an expression made up of? What do all expressions do?
# Ans:-
#
#
# An expression is a combination of values, variables, and operators that are compiled together.
# Expressions are used to  produce some value or result after being interpreted by the Python interpreter.
# ex.
#   a = a + 10
#   In this expression,first 10 is added to the variable a, After the addition is performed, the result is assigned to the variable a.
#
#
#
#
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
# Ans:-
#
#
# An expression is a combination of values, variables, and operators that are compiled together.
# A statement is an instruction that a Python interpreter can execute.
#
#
# ex.
# name = 'Anchal saini' #This is an assignment statement with assignment operator =.
#           result = 100/5*2+4     #Here 100/5*2+4 this is an expression and we are storing the result of this expression in                                       variable result.
#
#
#
#
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
#
# Ans:-
# bacon variable will still contain the value 22.
#
#
#
#
# 7. What should the values of the following two terms be?
#
# 'spam' + 'spamspam'
# 'spam' * 3
#
# Ans:-
#
# Value of the following two terms would be the same 'spamspamspam' .
#
#
#
#
#
# 8. Why is eggs a valid variable name while 100 is invalid?
#
# Ans:-
#
# In python variable name can not start with digit. variable name begin with a letter (a-z or A-Z) or an underscore (_).
# eggs start with letter, so it is a valid variable name and 100 starts with digit, so its invalid.
#
#
#
#
#
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
#
# Ans:-
#
# int(): This function is used to convert a value to an integer type.
# float(): This function is used to convert a value to a floating-point number type.
# str(): This function is used to convert a value to a string type.
#
#
#
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'
#
# Ans:-
#
# This expression cause error because we can only concatenate strings and string is the values inside the quotes.
# Here in this expression 99 is an integer because it is not inside quotes.
# that is why this expression causing error.
